# %% [markdown]
# <a href="https://colab.research.google.com/github/angel870326/Monthly-Revenue/blob/main/003_data_updating_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > 2023.03.03 Ssu-Yun Wang<br/>
# [Github @angel870326](https://github.com/angel870326)
#
# # **Update Missing Values from TWSE MOPS**
#
# ### Contents
#
# 1.  Read Data
#     *   Original Data
#     *   Data to be Updated
# 2.  Update Missing Values from TWSE MOPS
# 3.  Concatenate Datasets
# 4.  Output Data

# %%
# sConnect to the Google Drive
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## **1. Read Data**

# %%
# Data path
original_data_path = '/content/gdrive/Shareddrives/Me/論文/資料集/001_v1'
updated_data_path = '/content/gdrive/Shareddrives/Me/論文/資料集/002_v1'

# %% [markdown]
# ### **1.1 Original Data**

# %%
# 金融業：中間無缺值與有缺值
data_fin0 = pd.read_excel(os.path.join(original_data_path, '198801-202212上市櫃公司月營收_金融業_中間無缺值.xlsx'), index_col=0)
data_fin1 = pd.read_excel(os.path.join(original_data_path, '198801-202212上市櫃公司月營收_金融業_中間有缺值.xlsx'), index_col=0)
print("Data shape:", data_fin0.shape)
print("Data shape:", data_fin1.shape)
# Out:
# Data shape: (40, 420)
# Data shape: (2, 420)

# %%
# 非金融業：中間無缺值與有缺值
data_nonfin0 = pd.read_excel(os.path.join(original_data_path, '198801-202212上市櫃公司月營收_非金融業_中間無缺值.xlsx'), index_col=0)
data_nonfin1 = pd.read_excel(os.path.join(original_data_path, '198801-202212上市櫃公司月營收_非金融業_中間有缺值.xlsx'), index_col=0)
print("Data shape:", data_nonfin0.shape)
print("Data shape:", data_nonfin1.shape)
# Out:
# Data shape: (1595, 420)
# Data shape: (143, 420)

# %%
data_nonfin1.head()
# Out:
#               1988-01  1988-02  1988-03  1988-04  1988-05  1988-06  1988-07  \
# 公司
# 1240 茂生農經         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1256 鮮活果汁-KY      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1337 再生-KY        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1338 廣華-KY        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1339 昭輝           NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#               1988-08  1988-09  1988-10  ...  2022-03  2022-04  2022-05  \
# 公司                                       ...
# 1240 茂生農經         NaN      NaN      NaN  ...   274367   290585   292443
# 1256 鮮活果汁-KY      NaN      NaN      NaN  ...   333241   194594   399569
# 1337 再生-KY        NaN      NaN      NaN  ...    30368    53408    45114
# 1338 廣華-KY        NaN      NaN      NaN  ...   722919   417500   509475
# 1339 昭輝           NaN      NaN      NaN  ...   160802   177505   166991
#
#               2022-06  2022-07   2022-08  2022-09  2022-10  2022-11  2022-12
# 公司
# 1240 茂生農經      292475   262129  281860.0   281078   312492   286961   309199
# 1256 鮮活果汁-KY   409929   475276  581403.0   482664   142872   183937   340614
# 1337 再生-KY      48002    53666   60295.0    65786    48082    53325    73922
# 1338 廣華-KY     685917   705668  617345.0   635751   601039   602967   464981
# 1339 昭輝        155001   179434  175239.0   151164   170130   177450   154272
#
# [5 rows x 420 columns]

# %% [markdown]
# ### **1.2 Data to be Updated**
#
# From *002_data_missing_v1.ipynb*

# %%
# 補值列表
fin_nan_month = pd.read_excel(os.path.join(updated_data_path,'上市櫃公司月營收_金融業_補值.xlsx'))
nonfin_nan_month = pd.read_excel(os.path.join(updated_data_path,'上市櫃公司月營收_非金融業_補值.xlsx'))
print("金融業", fin_nan_month.shape)
print("非金融業", nonfin_nan_month.shape)
# Out:
# 金融業 (143, 3)
# 非金融業 (2643, 3)

# %%
nonfin_nan_month.head()
# Out:
#           公司       年月  當月營收（千元）
# 0  1240 茂生農經  2004-10       NaN
# 1  1240 茂生農經  2004-11       NaN
# 2  1240 茂生農經  2004-12       NaN
# 3  1240 茂生農經  2005-01       NaN
# 4  1240 茂生農經  2005-02       NaN

# %% [markdown]
# ## **2. Update Missing Values from TWSE MOPS**
#
# 根據補值列表更新原始檔案

# %%
# 計算原始檔案有多少缺失值（用於後續確認是否正確補值）
fin_nan_count_o = data_fin1.isna().sum().sum()
nonfin_nan_count_o = data_nonfin1.isna().sum().sum()

# 計算需補值的數量（補值表中不是空值的個數）
fin_to_update = fin_nan_month['當月營收（千元）'].notna().sum()
nonfin_to_update = nonfin_nan_month['當月營收（千元）'].notna().sum()

print("   data_fin1 NaN 總數：{}   待補值數：{}\ndata_nonfin1 NaN 總數：{} 待補值數：{}".format(fin_nan_count_o, fin_to_update, nonfin_nan_count_o, nonfin_to_update))
# Out:
#    data_fin1 NaN 總數：431   待補值數：10
# data_nonfin1 NaN 總數：32882 待補值數：439

# %%
# Update the original data
def updateMissingData(originalD: pd.DataFrame, updatedD: pd.DataFrame):
  for index, row in updatedD.iterrows():
    revenue = row['當月營收（千元）']
    if ~np.isnan(revenue): # if not NaN
      originalD.at[row['公司'], row['年月']] = revenue

updateMissingData(data_fin1, fin_nan_month)
updateMissingData(data_nonfin1, nonfin_nan_month)

# %%
# 計算補完值後有多少缺失值
fin_nan_count_new = data_fin1.isna().sum().sum()
nonfin_nan_count_new = data_nonfin1.isna().sum().sum()

# 確認是否正確補值
check_fin = check_nonfin = "error"
if fin_nan_count_new == fin_nan_count_o - fin_to_update:
  check_fin = "correct"
if nonfin_nan_count_new == nonfin_nan_count_o - nonfin_to_update:
  check_nonfin = "correct"

print("   data_fin1 更新後 NaN 總數：{}   ({})\ndata_nonfin1 更新後 NaN 總數：{} ({})".format(fin_nan_count_o, check_fin, nonfin_nan_count_o, check_nonfin))
# Out:
#    data_fin1 更新後 NaN 總數：431   (correct)
# data_nonfin1 更新後 NaN 總數：32882 (correct)

# %% [markdown]
# ## **3. Concatenate Datasets**
#
# data_fin_new & data_nonfin_new

# %%
# Sort the dataset by company id after concatenating
data_fin_new = pd.concat([data_fin0, data_fin1]).sort_index(ascending=True)
data_nonfin_new = pd.concat([data_nonfin0, data_nonfin1]).sort_index(ascending=True)

# 6023 元大期         NaN        NaN        NaN        NaN        NaN        NaN
# 6024 群益期         NaN        NaN        NaN        NaN        NaN        NaN
# 6026 福邦證         NaN        NaN        NaN        NaN        NaN        NaN
#
#              1988-07    1988-08    1988-09    1988-10  ...   2022-03  \
# 公司                                                     ...
# 2801 彰銀    2285566.0  2399543.0  2354405.0  2683718.0  ...   2822015
# 2809 京城銀    115815.0   119916.0   122163.0   122763.0  ...   -347984
# 2812 台中銀    216227.0   220798.0   221718.0   229814.0  ...   1265168
# 2816 旺旺保         NaN        NaN        NaN        NaN  ...    740703
# 2820 華票          NaN        NaN        NaN        NaN  ...    149300
# 2832 台產          NaN        NaN        NaN        NaN  ...    491847
# 2834 臺企銀         NaN        NaN        NaN        NaN  ...   2049170
# 2836 高雄銀         NaN        NaN        NaN        NaN  ...    350498
# 2838 聯邦銀         NaN        NaN        NaN        NaN  ...    946213
# 2845 遠東銀         NaN        NaN        NaN        NaN  ...    866867
# 2849 安泰銀         NaN        NaN        NaN        NaN  ...    567480
# 2850 新產          NaN        NaN        NaN        NaN  ...   1546306
# 2851 中再保         NaN        NaN        NaN        NaN  ...   1581318
# 2852 第一保         NaN        NaN        NaN        NaN  ...    578540
# 2855 統一證         NaN        NaN        NaN        NaN  ...    458954
# 2867 三商壽         NaN        NaN        NaN        NaN  ...  10742537
# 2880 華南金         NaN        NaN        NaN        NaN  ...   4978172
# 2881 富邦金         NaN        NaN        NaN        NaN  ...  31480552
# 2882 國泰金         NaN        NaN        NaN        NaN  ...  50651195
# 2883 開發金         NaN        NaN        NaN        NaN  ...  15874987
# 2884 玉山金         NaN        NaN        NaN        NaN  ...   4682565
# 2885 元大金         NaN        NaN        NaN        NaN  ...   9098851
# 2886 兆豐金         NaN        NaN        NaN        NaN  ...   5529313
# 2887 台新金         NaN        NaN        NaN        NaN  ...   5568364
# 2888 新光金         NaN        NaN        NaN        NaN  ...  16069359
# 2889 國票金         NaN        NaN        NaN        NaN  ...    486407
# 2890 永豐金         NaN        NaN        NaN        NaN  ...   4473021
# 2891 中信金         NaN        NaN        NaN        NaN  ...  16276440
# 2892 第一金         NaN        NaN        NaN        NaN  ...   6032273
# 2897 王道銀行        NaN        NaN        NaN        NaN  ...    699003
# 5864 致和證         NaN        NaN        NaN        NaN  ...    107884
# 5876 上海商銀        NaN        NaN        NaN        NaN  ...   3959090
# 5878 台名          NaN        NaN        NaN        NaN  ...     75036
# 5880 合庫金         NaN        NaN        NaN        NaN  ...   3951327
# 6005 群益證         NaN        NaN        NaN        NaN  ...    789926
# 6015 宏遠證         NaN        NaN        NaN        NaN  ...     94367
# 6016 康和證         NaN        NaN        NaN        NaN  ...    235603
# 6020 大展證         NaN        NaN        NaN        NaN  ...    -16578
# 6021 美好證         NaN        NaN        NaN        NaN  ...     83412
# 6026 福邦證    -158114    110230   -177109     -3862     86846      3964
#
#             2022-10   2022-11   2022-12
# 公司
# 2801 彰銀     2707237   3149417   3143300
# 2809 京城銀     525434   1159759    729033
# 2812 台中銀    1186838   1340389   1338751
# 2816 旺旺保     737689    821500    810501
# 2820 華票       57005    -18652    201445
# 2832 台產      497959    454014    516059
# 2834 臺企銀    2937436   2285810   2627259
# 2836 高雄銀     301110    312340    308750
# 2838 聯邦銀    1308647   1530112   1393577
# 2845 遠東銀    1026802   1163514   1189258
# 2849 安泰銀     486792    453932    448703
# 2850 新產     1639207   1582457   1586717
# 2851 中再保    1465832   1528279   1780345
# 2852 第一保     583428    564602    524695
# 2855 統一證     396305    710376    570959
# 2867 三商壽    9327009   7767209   9139491
# 2880 華南金    3952126   4101134   3781485
# 2881 富邦金   -5859934 -28846346   3343545
# 2882 國泰金   16822289   1584494  17233019
# 2883 開發金    2392523  -5620305   -130608
# 2884 玉山金    4416081   5177501   5167780
# 2885 元大金    5695834   4191095   6384408
# 2886 兆豐金    3132932   5358160   5487929
# 2887 台新金    7799491   6331683   4920669
# 2888 新光金    2749417  -5099494  -4022463
# 2889 國票金     235745    570796    367184
# 2890 永豐金    3436145   3220328   3530111
# 2891 中信金    3374417  -2440518   1625695
# 2892 第一金    5147509   5249687   5153601
# 2897 王道銀行    690542    536610   3923076
# 5864 致和證    -145298    196519     47020
# 5876 上海商銀   3714496   3707846   3812959
# 5878 台名       71887     56992     77804
# 5880 合庫金    4088455   4888866   4993820
# 6005 群益證     500932   1084063    831599
# 6015 宏遠證     -33182     77222     54324
# 6016 康和證      -4466    453256    126506
# 6020 大展證      -5489     42446     10606
# 6021 美好證      45003     24883     50952
# 6023 元大期     383115    334425    290790
# 6024 群益期     259764    210912    218035
# 6026 福邦證    -122331    183950     29387
#
# [42 rows x 420 columns]

# %% [markdown]
# ## **4. Output Data**

# %%
# Output data path
output_data_path = '/content/gdrive/Shareddrives/Me/論文/資料集'

# %%
# 中間有缺值的公司補值後的更新檔
data_fin1.to_excel(os.path.join(output_data_path,'198801-202212上市櫃公司月營收_金融業_中間有缺值_new.xlsx'))
data_nonfin1.to_excel(os.path.join(output_data_path,'198801-202212上市櫃公司月營收_非金融業_中間有缺值_new.xlsx'))
print("Data shape:", data_fin1.shape)
print("Data shape:", data_nonfin1.shape)
# Out:
# Data shape: (2, 420)
# Data shape: (143, 420)

# %%
# 最終合併檔
data_fin_new.to_excel(os.path.join(output_data_path,'198801-202212上市櫃公司月營收_金融業_final.xlsx'))
data_nonfin_new.to_excel(os.path.join(output_data_path,'198801-202212上市櫃公司月營收_非金融業_final.xlsx'))
print("Data shape:", data_fin_new.shape)
print("Data shape:", data_nonfin_new.shape)
# Out:
# Data shape: (42, 420)
# Data shape: (1738, 420)
